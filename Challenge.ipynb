# %% [markdown]
# ## Import library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

# 1. Import Iris dataset
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

# 2. Explore Iris dataset
print(df.head())  # แสดงตัวอย่าง 5 แถวแรก
print(df.describe())  # ค่าสถิติโดยรวม
print(df['species'].value_counts())  # จำนวนตัวอย่างแต่ละคลาส

# 3. Plot Iris dataset
sns.pairplot(df, hue="species", markers=["o", "s", "D"])
plt.show()

# 4. Export Iris dataset to CSV
df.to_csv("iris_dataset.csv", index=False)
print("Dataset has been saved as 'iris_dataset.csv'")
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
# Dataset has been saved as 'iris_dataset.csv'

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /opt/anaconda3/lib/python3.12/site-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
afnan = yf.download("NVDA", start="2023-01-01", end="2025-03-15")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
afnan.head()
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           NVDA       NVDA       NVDA       NVDA       NVDA
# Date
# 2023-01-03  14.303280  14.983723  14.084459  14.838841  401277000
# 2023-01-04  14.736924  14.840839  14.229341  14.555074  431324000
# 2023-01-05  14.253320  14.552075  14.136415  14.479135  389168000
# 2023-01-06  14.846835  14.997712  14.022511  14.462150  405044000
# 2023-01-09  15.615204  16.042853  15.128602  15.271486  504231000

# %%
afnan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 551 entries, 2023-01-03 to 2025-03-14
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, NVDA)   551 non-null    float64
#  1   (High, NVDA)    551 non-null    float64
#  2   (Low, NVDA)     551 non-null    float64
#  3   (Open, NVDA)    551 non-null    float64
#  4   (Volume, NVDA)  551 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 25.8 KB

# %%
afnan.describe()
# Out:
# Price        Close        High         Low        Open        Volume
# Ticker        NVDA        NVDA        NVDA        NVDA          NVDA
# count   551.000000  551.000000  551.000000  551.000000  5.510000e+02
# mean     77.373429   78.824628   75.810856   77.425839  4.130053e+08
# std      42.607766   43.517548   41.729842   42.783320  1.693764e+08
# min      14.253320   14.552075   14.022511   14.462150  1.051570e+08
# 25%      42.385860   43.213475   41.837385   42.440580  3.002562e+08
# 50%      69.305977   69.727819   67.179776   68.293355  3.960940e+08
# 75%     121.009209  123.534107  117.782154  121.245119  4.879805e+08
# max     149.416245  153.115916  147.806407  153.015919  1.543911e+09

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
import matplotlib.pyplot as plt

# Plot the closing prices
afnan['Close'].plot(title="NVIDIA Stock Closing Price")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.show()

# %%
# Export the data to a CSV file
afnan.to_csv('nvidia_stock_data.csv')

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Display the first 5 rows
print(iris.head())

# Check for missing values
print(iris.isnull().sum())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Summary statistics
print(iris.describe())

# Check distribution of numerical features
iris.hist(figsize=(10, 6), bins=15, edgecolor='black')
plt.show()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=iris)
plt.show()

# %%
sns.pairplot(iris, hue="species")
plt.show()

# %%
plt.figure(figsize=(6, 6))
iris['species'].value_counts().plot.pie(autopct="%1.1f%%", startangle=90, cmap='viridis')
plt.ylabel("")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
import pandas as pd

# โหลด Iris Dataset
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# คำนวณและแสดง Heatmap ของ Correlation Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(iris_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Iris Dataset")
plt.show()

# %%
import pandas as pd
from sklearn import datasets

# โหลดข้อมูลไอริส
iris = datasets.load_iris()

# ตรวจสอบคีย์ที่มีใน iris
print(iris.keys())  # เพื่อดูว่ามีคีย์อะไรบ้าง

# สร้าง DataFrame
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# เพิ่มคอลัมน์ species จาก target
df['species'] = iris.target  

# แสดงจำนวนตัวอย่างของแต่ละ species
print(df['species'].value_counts())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])
# species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
df['species'] = df['species'].map(lambda x: iris.target_names[x])
print(df.head())  # แสดง 5 แถวแรก
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print(df.tail())
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Fetch NVIDIA stock data
nvda = yf.download('NVDA', start='2020-01-01', end='2025-01-01')

# Display the first 5 rows
print(nvda.head())

# Check for missing values
print(nvda.isnull().sum())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          NVDA      NVDA      NVDA      NVDA       NVDA
# Date
# 2020-01-02  5.972161  5.972161  5.892752  5.943285  237536000
# 2020-01-03  5.876573  5.920385  5.827533  5.852426  205384000
# 2020-01-06  5.901214  5.906442  5.757082  5.783220  262636000
# 2020-01-07  5.972660  6.018463  5.884537  5.929594  314856000
# 2020-01-08  5.983860  6.025184  5.928348  5.968427  277108000
# Price   Ticker
# Close   NVDA      0
# High    NVDA      0
# Low     NVDA      0
# Open    NVDA      0
# Volume  NVDA      0
# dtype: int64

# %%
# Summary statistics
print(nvda.describe())
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker         NVDA         NVDA         NVDA         NVDA          NVDA
# count   1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean      38.442412    39.152700    37.668200    38.446816  4.468056e+08
# std       38.230364    38.940871    37.485882    38.291771  1.877132e+08
# min        4.891977     5.229235     4.500420     4.984138  9.788400e+07
# 25%       13.571984    13.823135    13.336993    13.604012  3.084230e+08
# 50%       21.235976    21.742669    20.822684    21.170346  4.209180e+08
# 75%       45.622283    46.201832    44.966485    45.746718  5.467242e+08
# max      148.856064   152.865409   146.236457   149.325985  1.543911e+09

# %%
plt.figure(figsize=(12, 6))
plt.plot(nvda['Close'], label='Closing Price', color='blue')
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("NVIDIA Stock Closing Price Over Time")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
nvda['Close'].plot(title="NVIDIA Stock Closing Price", color='blue')
plt.xlabel("Date")
plt.ylabel("Close Price (USD)")
plt.show()

# %%
nvda['MA50'] = nvda['Close'].rolling(window=50).mean()
nvda['MA200'] = nvda['Close'].rolling(window=200).mean()

plt.figure(figsize=(12, 6))
plt.plot(nvda['Close'], label='Close Price', color='blue')
plt.plot(nvda['MA50'], label='50-day MA', color='red')
plt.plot(nvda['MA200'], label='200-day MA', color='green')
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("NVIDIA Stock Price with Moving Averages")
plt.legend()
plt.show()

# %%
nvda['Daily Return'] = nvda['Close'].pct_change()

plt.figure(figsize=(8, 5))
sns.histplot(nvda['Daily Return'].dropna(), bins=50, kde=True)
plt.xlabel("Daily Return")
plt.ylabel("Frequency")
plt.title("Distribution of NVIDIA Daily Returns")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=nvda[['Open', 'High', 'Low', 'Close']])
plt.title("Boxplot of Stock Prices")
plt.show()

# %%
# Compute correlation matrix
corr_matrix = nvda[['Open', 'High', 'Low', 'Close', 'Volume']].corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Stock Features")
plt.show()
